# %%
import sys
sys.path.append("../")
import os
os.chdir('../')
import matplotlib.pyplot as plt

# %%
import json
import argparse
import numpy as np
import pandas as pd
import copy
import gc
from collections import Counter, OrderedDict
from operator import itemgetter

from src.data.load_dataset import load_dataset

from src.utils.logger_functions import get_module_logger
from src.utils.json_dump import save_json
from src.utils.get_conf_mat import get_conf_mat

from src.features.drop_features import drop_features
from src.features.select_features import select_features
from src.features.base import load_features

from src.models.lightgbm import LightGBM, multi_weighted_logloss
from src.models.get_folds import get_StratifiedKFold
# Out:
# /home/hakubishin3/work/kaggle_plasticc/src/utils/get_conf_mat.py:4: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/hakubishin3/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/hakubishin3/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/hakubishin3/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/hakubishin3/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2666, in run_cell
#     self.events.trigger('post_run_cell', result)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/IPython/core/events.py", line 88, in trigger
#     func(*args, **kwargs)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 160, in configure_once
#     activate_matplotlib(backend)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/hakubishin3/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/home/hakubishin3/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')

# %%
config = json.load(open("configs/lightgbm_35.json"))
logger = get_module_logger(__name__)
debug = False

# load dataset
# read only metadata.
logger.info('load dataset.')
train_meta, test_meta = load_dataset(config, 'meta', debug)
logger.debug(f'train_meta: {train_meta.shape}, test_meta: {test_meta.shape}')

# load features
logger.info('load features')
x_train, x_test = load_features(config, debug)
logger.debug(f'number of features: {x_train.shape[1]}')
# Out:
# 2018-11-29 16:34:47,556 [__main__] [INFO] load dataset.
# 2018-11-29 16:34:52,470 [__main__] [DEBUG] train_meta: (7848, 12), test_meta: (3492890, 11)
# 2018-11-29 16:34:52,471 [__main__] [INFO] load features
# /home/hakubishin3/anaconda3/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)
# 2018-11-29 16:38:14,503 [__main__] [DEBUG] number of features: 872

# %%
# check classes
classes = [6, 15, 16, 42, 52, 53, 62, 64, 65, 67, 88, 90, 92, 95]
class_weights = {6: 1.00104, 15: 2.00189, 16: 1.00104, 42: 1.00104, 52: 1.00104, 53: 1.00000, 62: 1.00104,
                 64: 2.00710, 65: 1.00104, 67: 1.00104, 88: 1.00104, 90: 1.00104, 92: 1.00104, 95: 1.00104}

# galastic vs extra-galastic
gal_classes = [6, 16, 53, 65, 92]
exgal_classes = [15, 42, 52, 62, 64, 67, 88, 90, 95]
gal_class_weights = {k: v for k, v in class_weights.items() if k in gal_classes}
exgal_class_weights = {k: v for k, v in class_weights.items() if k in exgal_classes}

# %%
train_gal_index = train_meta.query("hostgal_photoz == 0").index
train_exgal_index = train_meta.query("hostgal_photoz != 0").index
x_train_gal = x_train.loc[train_gal_index].reset_index(drop=True)
x_train_exgal = x_train.loc[train_exgal_index].reset_index(drop=True)

x_train_gal.dropna(how="all", axis=1, inplace=True)     # 全ての値が欠損である列を除外
x_train_exgal.dropna(how="all", axis=1, inplace=True)   # 全ての値が欠損である列を除外
std_gal = x_train_gal.apply(lambda x: np.std(x.dropna()))
x_train_gal.drop(std_gal[std_gal == 0].index.tolist(), axis=1, inplace=True)   # 同じ値しか持たない列を除外
std_exgal = x_train_exgal.apply(lambda x: np.std(x.dropna()))
x_train_exgal.drop(std_exgal[std_exgal == 0].index.tolist(), axis=1, inplace=True)   # 同じ値しか持たない列を除外
logger.debug(f'x_train_gal: {x_train_gal.shape}')
logger.debug(f'x_train_exgal: {x_train_exgal.shape}')
# Out:
# 2018-11-29 16:38:15,406 [__main__] [DEBUG] x_train_gal: (2325, 762)
# 2018-11-29 16:38:15,407 [__main__] [DEBUG] x_train_exgal: (5523, 834)

# %%
test_gal_index = test_meta.query("hostgal_photoz == 0").index
test_exgal_index = test_meta.query("hostgal_photoz != 0").index
x_test_gal = x_test.loc[test_gal_index].reset_index(drop=True)
x_test_exgal = x_test.loc[test_exgal_index].reset_index(drop=True)
test_gal_objectid = test_meta.query("hostgal_photoz == 0").object_id.values
test_exgal_objectid = test_meta.query("hostgal_photoz != 0").object_id.values

# %% [markdown]
# - lightgbm_35.jsonについて
# - LB: 0.975

# %%
output_35 = json.load(open("./data/output/output_42.json"))
gal_cols = [*output_35["evals_result_gal"]["feature_importance"].keys()]
exgal_cols = [*output_35["evals_result_exgal"]["feature_importance"].keys()]
len(gal_cols), len(exgal_cols)
# Out:
# (60, 100)

# %%
from IPython.display import display
display(x_train_gal[gal_cols].isnull().sum().sort_values(ascending=False))
display(x_test_gal[gal_cols].isnull().sum().sort_values(ascending=False))
# Out:
# fluxdiff_median_detected1      17
# fluxdiff_min_detected1         17
# fluxdiff_mean_detected1        17
# minimum_y                       0
# flux_err_min                    0
# median_absolute_deviation_i     0
# percent_close_to_median_y       0
# median_absolute_deviation_y     0
# skew_u                          0
# median_u                        0
# flux_median                     0
# maximum_y                       0
# flux_dif2                       0
# period_fast_y                   0
# stetson_j_y                     0
# median_absolute_deviation_g     0
# std_z                           0
# period_fast_z                   0
# flux_min_detected1              0
# skew_z                          0
# flux_by_flux_ratio_sq_skew      0
# __freq_varrat___5_              0
# period_fast_r                   0
# skew_i                          0
# skew_g                          0
# qso_log_chi2_qsonu_u            0
# median_absolute_deviation_r     0
# flux_skew                       0
# skew_r                          0
# median_r                        0
# detected_mean                   0
# flux_ratio_sq_skew              0
# __linear_trend___4_             0
# stetson_k_i                     0
# maximum_z                       0
# mean_z                          0
# percent_close_to_median_i       0
# weighted_average_z              0
# flux_w_mean_detected1           0
# flux_w_mean                     0
# stetson_k_z                     0
# median_z                        0
# stetson_k_y                     0
# avg_err_g                       0
# weighted_average_r              0
# percent_close_to_median_z       0
# amplitude_y                     0
# qso_log_chi2_qsonu_y            0
# minimum_g                       0
# median_y                        0
# __freq_y_offset___3_            0
# weighted_average_y              0
# stetson_j_z                     0
# skew_y                          0
# period_fast_i                   0
# std_y                           0
# stetson_j_r                     0
# minimum_r                       0
# stetson_j_g                     0
# diff_mjd_maxmin_detected1       0
# dtype: int64
# fluxdiff_median_detected1      2196
# fluxdiff_mean_detected1        2196
# fluxdiff_min_detected1         2196
# __freq_y_offset___3_              4
# qso_log_chi2_qsonu_u              3
# __freq_varrat___5_                2
# period_fast_y                     0
# flux_dif2                         0
# maximum_y                         0
# minimum_y                         0
# stetson_j_y                       0
# median_u                          0
# skew_u                            0
# median_absolute_deviation_y       0
# percent_close_to_median_y         0
# median_absolute_deviation_i       0
# flux_median                       0
# median_absolute_deviation_g       0
# median_r                          0
# period_fast_z                     0
# flux_min_detected1                0
# skew_z                            0
# flux_by_flux_ratio_sq_skew        0
# period_fast_r                     0
# skew_i                            0
# skew_g                            0
# median_absolute_deviation_r       0
# flux_skew                         0
# skew_r                            0
# flux_err_min                      0
# detected_mean                     0
# std_z                             0
# __linear_trend___4_               0
# stetson_k_i                       0
# maximum_z                         0
# mean_z                            0
# percent_close_to_median_i         0
# weighted_average_z                0
# flux_w_mean_detected1             0
# flux_w_mean                       0
# stetson_k_z                       0
# median_z                          0
# stetson_k_y                       0
# avg_err_g                         0
# weighted_average_r                0
# percent_close_to_median_z         0
# flux_ratio_sq_skew                0
# qso_log_chi2_qsonu_y              0
# minimum_g                         0
# median_y                          0
# weighted_average_y                0
# stetson_j_z                       0
# skew_y                            0
# period_fast_i                     0
# std_y                             0
# stetson_j_r                       0
# minimum_r                         0
# stetson_j_g                       0
# amplitude_y                       0
# diff_mjd_maxmin_detected1         0
# dtype: int64

# %%
from IPython.display import display
display(x_train_exgal[exgal_cols].isnull().sum().sort_values(ascending=False))
display(x_test_exgal[exgal_cols].isnull().sum().sort_values(ascending=False))
# Out:
# fluxdiff_median_detected1                 79
# fluxdiff_dif2_detected1                   79
# fluxdiff_max_detected1                    79
# fluxdiff_min_detected1                    79
# __freq_varrat___0_                         1
# flux_mean_detected1_fluxfactor             0
# mean_y                                     0
# maximum_u                                  0
# flux_w_mean_1_fluxfactor                   0
# median_absolute_deviation_r                0
# flux_skew_fluxfactor                       0
# flux_std_detected1                         0
# weighted_average_y                         0
# period_fast_i                              0
# median_absolute_deviation_g                0
# hostgal_photoz_certain                     0
# __freq_varrat___5_                         0
# period_fast_y                              0
# distmod                                    0
# skew_i                                     0
# flux_by_flux_ratio_sq_sum_1_fluxfactor     0
# qso_log_chi2_qsonu_y                       0
# hostgal_photoz_err                         0
# __freq_varrat___3_                         0
# flux_by_flux_ratio_sq_sum_5_fluxfactor     0
# skew_r                                     0
# flux_skew                                  0
# flux_median_fluxfactor                     0
# __freq_varrat___4_                         0
# median_g                                   0
#                                           ..
# __freq3_freq___2_                          0
# fluxdiff_skew_2                            0
# __freq3_rel_phase4___5_                    0
# flux_dif2_detected1_fluxfactor             0
# flux_dif2_fluxfactor                       0
# median_absolute_deviation_z                0
# mean_u                                     0
# __freq_varrat___2_                         0
# flux_by_flux_ratio_sq_sum_0_fluxfactor     0
# qso_log_chi2_qsonu_u                       0
# stetson_j_u                                0
# percent_close_to_median_r                  0
# flux_dif2_2_fluxfactor                     0
# flux_by_flux_ratio_sq_skew_fluxfactor      0
# __freq_varrat___1_                         0
# median_i                                   0
# flux_diff_fluxfactor                       0
# flux_w_mean_detected1_fluxfactor           0
# flux_mean_detected1                        0
# flux_dif3_detected1                        0
# flux_by_flux_ratio_sq_skew                 0
# flux_err_min_fluxfactor                    0
# skew_y                                     0
# weighted_average_g                         0
# mean_g                                     0
# flux_dif3                                  0
# flux_dif3_detected1_fluxfactor             0
# flux_max_fluxfactor                        0
# median_z                                   0
# diff_mjd_maxmin_detected1                  0
# Length: 100, dtype: int64
# fluxdiff_dif2_detected1                   91239
# fluxdiff_min_detected1                    91238
# fluxdiff_median_detected1                 91238
# fluxdiff_max_detected1                    91238
# __freq_varrat___0_                          199
# __freq_varrat___1_                          100
# stetson_j_u                                  49
# period_fast_u                                49
# qso_log_chi2_qsonu_u                         49
# fluxdiff_skew_3                              34
# __freq_varrat___2_                           26
# __freq_varrat___3_                           19
# fluxdiff_skew_2                              15
# __freq3_rel_phase4___5_                       6
# __freq_varrat___4_                            4
# __freq_varrat___5_                            4
# fluxdiff_min_2                                3
# fluxdiff_diff_2                               3
# flux_skew_fluxfactor                          0
# flux_std_detected1                            0
# period_fast_i                                 0
# weighted_average_y                            0
# period_fast_y                                 0
# mean_y                                        0
# hostgal_photoz_certain                        0
# median_absolute_deviation_g                   0
# flux_w_mean_1_fluxfactor                      0
# distmod                                       0
# skew_i                                        0
# flux_by_flux_ratio_sq_sum_1_fluxfactor        0
#                                           ...
# flux_ratio_sq_skew                            0
# flux_mean_fluxfactor                          0
# flux_std_fluxfactor                           0
# flux_dif3_fluxfactor                          0
# __freq3_freq___2_                             0
# flux_dif2_detected1_fluxfactor                0
# flux_dif2_1_fluxfactor                        0
# median_z                                      0
# skew_g                                        0
# flux_max_fluxfactor                           0
# median_g                                      0
# flux_diff_detected1_fluxfactor                0
# mean_u                                        0
# flux_by_flux_ratio_sq_sum_0_fluxfactor        0
# percent_close_to_median_r                     0
# flux_dif2_2_fluxfactor                        0
# flux_by_flux_ratio_sq_skew_fluxfactor         0
# median_i                                      0
# flux_diff_fluxfactor                          0
# flux_w_mean_detected1_fluxfactor              0
# flux_mean_detected1                           0
# flux_dif3_detected1                           0
# flux_by_flux_ratio_sq_skew                    0
# flux_err_min_fluxfactor                       0
# skew_y                                        0
# weighted_average_g                            0
# mean_g                                        0
# flux_dif3                                     0
# flux_dif3_detected1_fluxfactor                0
# diff_mjd_maxmin_detected1                     0
# Length: 100, dtype: int64

# %%
output_38 = json.load(open("./kaggle_plasticc/data/output/output_38.json"))
gal_cols = [*output_38["evals_result_gal"]["feature_importance"].keys()]
exgal_cols = [*output_38["evals_result_exgal"]["feature_importance"].keys()]
len(gal_cols), len(exgal_cols)
# Out:
# (30, 150)

# %%
from IPython.display import display
display(x_train_gal[gal_cols].isnull().sum().sort_values(ascending=False))
display(x_test_gal[gal_cols].isnull().sum().sort_values(ascending=False))
# Out:
# flux_skew_detected1            423
# percent_amplitude_r            111
# fluxdiff_mean_detected1         17
# fluxdiff_median_detected1       17
# fluxdiff_min_detected1          17
# skew_y                           0
# skew_z                           0
# weighted_average_y               0
# median_absolute_deviation_r      0
# period_fast_y                    0
# median_absolute_deviation_y      0
# std_y                            0
# flux_by_flux_ratio_sq_skew       0
# skew_i                           0
# median_absolute_deviation_g      0
# flux_skew                        0
# skew_r                           0
# percent_close_to_median_y        0
# qso_log_chi2_qsonu_u             0
# flux_ratio_sq_skew               0
# stetson_j_y                      0
# flux_dif2                        0
# period_fast_z                    0
# flux_min_detected1               0
# period_fast_r                    0
# median_r                         0
# percent_close_to_median_z        0
# period_fast_i                    0
# skew_g                           0
# diff_mjd_maxmin_detected1        0
# dtype: int64
# percent_amplitude_r            73983
# flux_skew_detected1            55133
# fluxdiff_mean_detected1         2196
# fluxdiff_median_detected1       2196
# fluxdiff_min_detected1          2196
# qso_log_chi2_qsonu_u               3
# skew_y                             0
# flux_skew                          0
# weighted_average_y                 0
# median_absolute_deviation_r        0
# period_fast_y                      0
# median_absolute_deviation_y        0
# std_y                              0
# flux_by_flux_ratio_sq_skew         0
# skew_i                             0
# median_absolute_deviation_g        0
# skew_r                             0
# skew_z                             0
# percent_close_to_median_y          0
# flux_ratio_sq_skew                 0
# stetson_j_y                        0
# flux_dif2                          0
# period_fast_z                      0
# flux_min_detected1                 0
# period_fast_r                      0
# median_r                           0
# percent_close_to_median_z          0
# period_fast_i                      0
# skew_g                             0
# diff_mjd_maxmin_detected1          0
# dtype: int64

# %%
from IPython.display import display
display(x_train_exgal[cols].isnull().sum().sort_values(ascending=False))
display(x_test_exgal[cols].isnull().sum().sort_values(ascending=False))
# Out:
# peakpoint_pass0-pass4                              4071
# peakpoint_pass0-pass3                              4040
# peakpoint_pass1-pass5                              3121
# time_from_peak_after_thres0.1_pass4                2746
# peakpoint_pass2-pass5                              2697
# time_from_peak_after_thres0.2_pass4                2679
# peakpoint_pass3-pass5                              2630
# time_from_peak_after_thres0.3_pass4                2624
# time_from_peak_after_thres0.1_pass3                2587
# time_from_peak_after_thres0.4_pass4                2576
# time_from_peak_after_thres0.5_pass4                2526
# time_from_peak_after_thres0.2_pass3                2517
# time_from_peak_after_thres0.6_pass4                2477
# time_from_peak_after_thres0.3_pass3                2453
# time_from_peak_after_thres0.4_pass3                2407
# time_from_peak_after_thres0.1_pass2                2397
# peakpoint_pass1-pass4                              2375
# time_from_peak_after_thres0.2_pass2                2330
# time_from_peak_after_thres0.3_pass2                2278
# time_from_peak_after_thres0.4_pass2                2226
# time_from_peak_after_thres0.5_pass2                2197
# time_from_peak_after_thres0.6_pass2                2163
# peakpoint_pass2-pass4                              1550
# peakpoint_pass3-pass4                              1430
# fluxdiff_skew_detected1                             788
# flux_by_flux_ratio_sq_skew_detected1_fluxfactor     466
# flux_skew_detected1_fluxfactor                      466
# flux_err_skew_detected1                             466
# flux_by_flux_ratio_sq_skew_detected1                466
# flux_skew_detected1                                 466
#                                                    ...
# skew_g                                                0
# fluxdiff_skew_2                                       0
# flux_max_detected1_fluxfactor                         0
# flux_median                                           0
# flux_max_fluxfactor                                   0
# period_fast_y                                         0
# flux_by_flux_ratio_sq_skew                            0
# flux_dif2_1_fluxfactor                                0
# flux_diff_fluxfactor                                  0
# mean_y                                                0
# flux_median_detected1_fluxfactor                      0
# __freq1_signif___2_                                   0
# mean_g                                                0
# __freq_varrat___3_                                    0
# qso_log_chi2_qsonu_y                                  0
# flux_err_max_detected1_fluxfactor                     0
# flux_min_detected1_fluxfactor                         0
# skew_z                                                0
# stetson_j_g                                           0
# flux_dif3_detected1_fluxfactor                        0
# flux_dif3_fluxfactor                                  0
# percent_close_to_median_r                             0
# maximum_y                                             0
# fluxdiff_max_2                                        0
# flux_by_flux_ratio_sq_sum_1_fluxfactor                0
# qso_log_chi2_qsonu_g                                  0
# flux_w_mean_fluxfactor                                0
# stetson_j_y                                           0
# flux_ratio_sq_skew                                    0
# diff_mjd_maxmin_detected1                             0
# Length: 150, dtype: int64
# peakpoint_pass0-pass4                              2967875
# peakpoint_pass0-pass3                              2942949
# peakpoint_pass1-pass5                              2812905
# peakpoint_pass2-pass5                              2710778
# peakpoint_pass3-pass5                              2698158
# time_from_peak_after_thres0.1_pass4                2545741
# time_from_peak_after_thres0.2_pass4                2538592
# time_from_peak_after_thres0.3_pass4                2531684
# time_from_peak_after_thres0.4_pass4                2525256
# time_from_peak_after_thres0.5_pass4                2519029
# time_from_peak_after_thres0.6_pass4                2513296
# peakpoint_pass1-pass4                              2440311
# time_from_peak_after_thres0.1_pass3                2129555
# time_from_peak_after_thres0.2_pass3                2117038
# time_from_peak_after_thres0.3_pass3                2105253
# time_from_peak_after_thres0.4_pass3                2094011
# peakpoint_pass2-pass4                              1971063
# peakpoint_pass3-pass4                              1944836
# time_from_peak_after_thres0.1_pass2                1900694
# time_from_peak_after_thres0.2_pass2                1885658
# time_from_peak_after_thres0.3_pass2                1872099
# time_from_peak_after_thres0.4_pass2                1859340
# time_from_peak_after_thres0.5_pass2                1847260
# time_from_peak_after_thres0.6_pass2                1835488
# fluxdiff_skew_detected1                            1203297
# flux_by_flux_ratio_sq_skew_detected1_fluxfactor     910812
# flux_err_skew_detected1                             910812
# flux_by_flux_ratio_sq_skew_detected1                910812
# flux_skew_detected1                                 910812
# flux_skew_detected1_fluxfactor                      910812
#                                                     ...
# flux_mean_detected1_fluxfactor                           0
# flux_mean_fluxfactor                                     0
# skew_g                                                   0
# flux_ratio_sq_skew                                       0
# mean_g                                                   0
# flux_w_mean_detected1_fluxfactor                         0
# flux_max_detected1_fluxfactor                            0
# flux_median                                              0
# flux_max_fluxfactor                                      0
# period_fast_y                                            0
# flux_by_flux_ratio_sq_skew                               0
# flux_dif2_1_fluxfactor                                   0
# flux_diff_fluxfactor                                     0
# mean_y                                                   0
# flux_median_detected1_fluxfactor                         0
# __freq1_signif___2_                                      0
# qso_log_chi2_qsonu_y                                     0
# stetson_j_y                                              0
# flux_err_max_detected1_fluxfactor                        0
# flux_min_detected1_fluxfactor                            0
# skew_z                                                   0
# stetson_j_g                                              0
# flux_dif3_detected1_fluxfactor                           0
# flux_dif3_fluxfactor                                     0
# percent_close_to_median_r                                0
# maximum_y                                                0
# flux_by_flux_ratio_sq_sum_1_fluxfactor                   0
# qso_log_chi2_qsonu_g                                     0
# flux_w_mean_fluxfactor                                   0
# diff_mjd_maxmin_detected1                                0
# Length: 150, dtype: int64

# %%
output_39 = json.load(open("./kaggle_plasticc/data/output/output_39.json"))
cols = [*output_39["evals_result_exgal"]["feature_importance"].keys()]
len(cols)
# Out:
# 100

# %%
from IPython.display import display
display(x_train_exgal[cols].isnull().sum().sort_values(ascending=False))
display(x_test_exgal[cols].isnull().sum().sort_values(ascending=False))
# Out:
# peakpoint_pass1-pass5                              3121
# peakpoint_pass2-pass5                              2697
# peakpoint_pass3-pass5                              2630
# peakpoint_pass1-pass4                              2375
# peakpoint_pass2-pass4                              1550
# peakpoint_pass3-pass4                              1430
# fluxdiff_skew_detected1                             788
# flux_by_flux_ratio_sq_skew_detected1                466
# flux_skew_detected1_fluxfactor                      466
# flux_by_flux_ratio_sq_skew_detected1_fluxfactor     466
# flux_skew_detected1                                 466
# fluxdiff_std_detected1                              329
# fluxdiff_median_detected1                            79
# fluxdiff_dif2_detected1                              79
# fluxdiff_max_detected1                               79
# fluxdiff_min_detected1                               79
# __freq_varrat___0_                                    1
# median_absolute_deviation_g                           0
# stetson_k_r                                           0
# __freq_varrat___4_                                    0
# period_fast_z                                         0
# weighted_average_u                                    0
# __freq_varrat___5_                                    0
# period_fast_i                                         0
# qso_log_chi2_qsonu_y                                  0
# flux_dif2                                             0
# qso_log_chi2_qsonu_u                                  0
# flux_dif2_fluxfactor                                  0
# maximum_u                                             0
# period_fast_y                                         0
#                                                    ...
# flux_w_mean_fluxfactor                                0
# flux_dif2_5_fluxfactor                                0
# stetson_k_z                                           0
# flux_min_detected1_fluxfactor                         0
# flux_median                                           0
# flux_by_flux_ratio_sq_skew_fluxfactor                 0
# flux_std_detected1_fluxfactor                         0
# median_i                                              0
# weighted_average_g                                    0
# hostgal_photoz                                        0
# skew_i                                                0
# flux_dif2_2_fluxfactor                                0
# flux_max_detected1_fluxfactor                         0
# flux_std_detected1                                    0
# flux_diff_detected1_fluxfactor                        0
# flux_w_mean_detected1_fluxfactor                      0
# flux_median_detected1                                 0
# flux_by_flux_ratio_sq_skew                            0
# flux_dif3_detected1                                   0
# flux_by_flux_ratio_sq_sum_1_fluxfactor                0
# __freq_varrat___1_                                    0
# flux_skew_fluxfactor                                  0
# flux_dif3                                             0
# weighted_average_y                                    0
# skew_r                                                0
# flux_dif2_1_fluxfactor                                0
# mean_g                                                0
# percent_close_to_median_r                             0
# amplitude_u                                           0
# diff_mjd_maxmin_detected1                             0
# Length: 100, dtype: int64
# peakpoint_pass1-pass5                              2812905
# peakpoint_pass2-pass5                              2710778
# peakpoint_pass3-pass5                              2698158
# peakpoint_pass1-pass4                              2440311
# peakpoint_pass2-pass4                              1971063
# peakpoint_pass3-pass4                              1944836
# fluxdiff_skew_detected1                            1203297
# flux_by_flux_ratio_sq_skew_detected1_fluxfactor     910812
# flux_by_flux_ratio_sq_skew_detected1                910812
# flux_skew_detected1                                 910812
# flux_skew_detected1_fluxfactor                      910812
# fluxdiff_std_detected1                              390131
# fluxdiff_dif2_detected1                              91239
# fluxdiff_median_detected1                            91238
# fluxdiff_max_detected1                               91238
# fluxdiff_min_detected1                               91238
# __freq_varrat___0_                                     199
# __freq_varrat___1_                                     100
# qso_log_chi2_qsonu_u                                    49
# period_fast_u                                           49
# __freq_varrat___2_                                      26
# __freq_varrat___3_                                      19
# fluxdiff_skew_2                                         15
# __freq_varrat___4_                                       4
# __freq_varrat___5_                                       4
# fluxdiff_diff_2                                          3
# fluxdiff_min_2                                           3
# flux_dif3_detected1_fluxfactor                           0
# median_absolute_deviation_g                              0
# flux_by_flux_ratio_sq_sum_0_fluxfactor                   0
#                                                     ...
# mean_g                                                   0
# percent_close_to_median_r                                0
# amplitude_u                                              0
# flux_err_min_fluxfactor                                  0
# flux_diff_fluxfactor                                     0
# flux_max_fluxfactor                                      0
# skew_z                                                   0
# weighted_average_g                                       0
# flux_w_mean_4_fluxfactor                                 0
# median_i                                                 0
# flux_skew_fluxfactor                                     0
# skew_i                                                   0
# flux_w_mean_fluxfactor                                   0
# flux_mean_fluxfactor                                     0
# qso_log_chi2_qsonu_y                                     0
# flux_skew                                                0
# median_g                                                 0
# distmod                                                  0
# hostgal_photoz                                           0
# flux_dif2_2_fluxfactor                                   0
# flux_max_detected1_fluxfactor                            0
# flux_std_detected1                                       0
# flux_diff_detected1_fluxfactor                           0
# flux_std_fluxfactor                                      0
# flux_w_mean_detected1_fluxfactor                         0
# flux_dif2_detected1                                      0
# flux_median_detected1                                    0
# flux_by_flux_ratio_sq_skew                               0
# flux_dif3_detected1                                      0
# diff_mjd_maxmin_detected1                                0
# Length: 100, dtype: int64

# %%
x_train_exgal.isnull().sum()[x_train_exgal.isnull().sum() < 250].index.tolist()
# Out:
# ['hostgal_photoz',
#  'hostgal_photoz_err',
#  'distmod',
#  'mwebv',
#  'haversine',
#  'latlon1',
#  'hostgal_photoz_certain',
#  'flux_min',
#  'flux_max',
#  'flux_mean',
#  'flux_median',
#  'flux_std',
#  'flux_skew',
#  'flux_err_min',
#  'flux_err_max',
#  'flux_err_mean',
#  'flux_err_median',
#  'flux_err_std',
#  'flux_err_skew',
#  'detected_mean',
#  'flux_ratio_sq_sum',
#  'flux_ratio_sq_skew',
#  'flux_by_flux_ratio_sq_sum',
#  'flux_by_flux_ratio_sq_skew',
#  'diff_mjd_maxmin_detected1',
#  'flux_min_detected1',
#  'flux_max_detected1',
#  'flux_mean_detected1',
#  'flux_median_detected1',
#  'flux_std_detected1',
#  'flux_err_min_detected1',
#  'flux_err_max_detected1',
#  'flux_err_mean_detected1',
#  'flux_err_median_detected1',
#  'flux_err_std_detected1',
#  'flux_ratio_sq_sum_detected1',
#  'flux_by_flux_ratio_sq_sum_detected1',
#  'flux_diff',
#  'flux_dif2',
#  'flux_w_mean',
#  'flux_dif3',
#  'flux_diff_detected1',
#  'flux_dif2_detected1',
#  'flux_w_mean_detected1',
#  'flux_dif3_detected1',
#  'amplitude_u',
#  'amplitude_g',
#  'amplitude_r',
#  'amplitude_i',
#  'amplitude_z',
#  'amplitude_y',
#  'flux_percentile_ratio_mid20_u',
#  'flux_percentile_ratio_mid20_g',
#  'flux_percentile_ratio_mid20_r',
#  'flux_percentile_ratio_mid20_i',
#  'flux_percentile_ratio_mid20_z',
#  'flux_percentile_ratio_mid20_y',
#  'flux_percentile_ratio_mid35_u',
#  'flux_percentile_ratio_mid35_g',
#  'flux_percentile_ratio_mid35_r',
#  'flux_percentile_ratio_mid35_i',
#  'flux_percentile_ratio_mid35_z',
#  'flux_percentile_ratio_mid35_y',
#  'flux_percentile_ratio_mid50_u',
#  'flux_percentile_ratio_mid50_g',
#  'flux_percentile_ratio_mid50_r',
#  'flux_percentile_ratio_mid50_i',
#  'flux_percentile_ratio_mid50_z',
#  'flux_percentile_ratio_mid50_y',
#  'flux_percentile_ratio_mid65_u',
#  'flux_percentile_ratio_mid65_g',
#  'flux_percentile_ratio_mid65_r',
#  'flux_percentile_ratio_mid65_i',
#  'flux_percentile_ratio_mid65_z',
#  'flux_percentile_ratio_mid65_y',
#  'flux_percentile_ratio_mid80_u',
#  'flux_percentile_ratio_mid80_g',
#  'flux_percentile_ratio_mid80_r',
#  'flux_percentile_ratio_mid80_i',
#  'flux_percentile_ratio_mid80_z',
#  'flux_percentile_ratio_mid80_y',
#  'max_slope_u',
#  'max_slope_g',
#  'max_slope_r',
#  'max_slope_i',
#  'max_slope_z',
#  'max_slope_y',
#  'maximum_u',
#  'maximum_g',
#  'maximum_r',
#  'maximum_i',
#  'maximum_z',
#  'maximum_y',
#  'median_u',
#  'median_g',
#  'median_r',
#  'median_i',
#  'median_z',
#  'median_y',
#  'median_absolute_deviation_u',
#  'median_absolute_deviation_g',
#  'median_absolute_deviation_r',
#  'median_absolute_deviation_i',
#  'median_absolute_deviation_z',
#  'median_absolute_deviation_y',
#  'minimum_u',
#  'minimum_g',
#  'minimum_r',
#  'minimum_i',
#  'minimum_z',
#  'minimum_y',
#  'percent_amplitude_u',
#  'percent_amplitude_g',
#  'percent_amplitude_r',
#  'percent_amplitude_i',
#  'percent_amplitude_z',
#  'percent_amplitude_y',
#  'percent_beyond_1_std_u',
#  'percent_beyond_1_std_g',
#  'percent_beyond_1_std_r',
#  'percent_beyond_1_std_i',
#  'percent_beyond_1_std_z',
#  'percent_beyond_1_std_y',
#  'percent_close_to_median_u',
#  'percent_close_to_median_g',
#  'percent_close_to_median_r',
#  'percent_close_to_median_i',
#  'percent_close_to_median_z',
#  'percent_close_to_median_y',
#  'percent_difference_flux_percentile_u',
#  'percent_difference_flux_percentile_g',
#  'percent_difference_flux_percentile_r',
#  'percent_difference_flux_percentile_i',
#  'percent_difference_flux_percentile_z',
#  'percent_difference_flux_percentile_y',
#  'period_fast_u',
#  'period_fast_g',
#  'period_fast_r',
#  'period_fast_i',
#  'period_fast_z',
#  'period_fast_y',
#  'qso_log_chi2_qsonu_u',
#  'qso_log_chi2_qsonu_g',
#  'qso_log_chi2_qsonu_r',
#  'qso_log_chi2_qsonu_i',
#  'qso_log_chi2_qsonu_z',
#  'qso_log_chi2_qsonu_y',
#  'qso_log_chi2nuNULL_chi2nu_u',
#  'qso_log_chi2nuNULL_chi2nu_g',
#  'qso_log_chi2nuNULL_chi2nu_r',
#  'qso_log_chi2nuNULL_chi2nu_i',
#  'qso_log_chi2nuNULL_chi2nu_z',
#  'qso_log_chi2nuNULL_chi2nu_y',
#  'skew_u',
#  'skew_g',
#  'skew_r',
#  'skew_i',
#  'skew_z',
#  'skew_y',
#  'std_u',
#  'std_g',
#  'std_r',
#  'std_i',
#  'std_z',
#  'std_y',
#  'stetson_j_u',
#  'stetson_j_g',
#  'stetson_j_r',
#  'stetson_j_i',
#  'stetson_j_z',
#  'stetson_j_y',
#  'stetson_k_u',
#  'stetson_k_g',
#  'stetson_k_r',
#  'stetson_k_i',
#  'stetson_k_z',
#  'stetson_k_y',
#  'weighted_average_u',
#  'weighted_average_g',
#  'weighted_average_r',
#  'weighted_average_i',
#  'weighted_average_z',
#  'weighted_average_y',
#  'all_times_nhist_numpeaks_u',
#  'all_times_nhist_numpeaks_g',
#  'all_times_nhist_numpeaks_r',
#  'all_times_nhist_numpeaks_i',
#  'all_times_nhist_numpeaks_z',
#  'all_times_nhist_numpeaks_y',
#  'all_times_nhist_peak1_bin_u',
#  'all_times_nhist_peak1_bin_g',
#  'all_times_nhist_peak1_bin_r',
#  'all_times_nhist_peak1_bin_i',
#  'all_times_nhist_peak1_bin_z',
#  'all_times_nhist_peak1_bin_y',
#  'all_times_nhist_peak2_bin_u',
#  'all_times_nhist_peak2_bin_g',
#  'all_times_nhist_peak2_bin_r',
#  'all_times_nhist_peak2_bin_i',
#  'all_times_nhist_peak2_bin_z',
#  'all_times_nhist_peak2_bin_y',
#  'all_times_nhist_peak3_bin_u',
#  'all_times_nhist_peak4_bin_u',
#  'all_times_nhist_peak_1_to_2_u',
#  'all_times_nhist_peak_1_to_2_g',
#  'all_times_nhist_peak_1_to_2_r',
#  'all_times_nhist_peak_1_to_2_i',
#  'all_times_nhist_peak_1_to_2_z',
#  'all_times_nhist_peak_1_to_2_y',
#  'all_times_nhist_peak_1_to_3_u',
#  'all_times_nhist_peak_1_to_4_u',
#  'all_times_nhist_peak_2_to_3_u',
#  'all_times_nhist_peak_2_to_4_u',
#  'all_times_nhist_peak_3_to_4_u',
#  'all_times_nhist_peak_val_u',
#  'all_times_nhist_peak_val_g',
#  'all_times_nhist_peak_val_r',
#  'all_times_nhist_peak_val_i',
#  'all_times_nhist_peak_val_z',
#  'all_times_nhist_peak_val_y',
#  'avg_double_to_single_step_u',
#  'avg_double_to_single_step_g',
#  'avg_double_to_single_step_r',
#  'avg_double_to_single_step_i',
#  'avg_double_to_single_step_z',
#  'avg_double_to_single_step_y',
#  'avg_err_u',
#  'avg_err_g',
#  'avg_err_r',
#  'avg_err_i',
#  'avg_err_z',
#  'avg_err_y',
#  'avgt_u',
#  'avgt_g',
#  'avgt_r',
#  'avgt_i',
#  'avgt_z',
#  'avgt_y',
#  'cad_probs_30_u',
#  'cad_probs_30_g',
#  'cad_probs_30_r',
#  'cad_probs_30_i',
#  'cad_probs_30_z',
#  'cad_probs_40_u',
#  'cad_probs_40_g',
#  'cad_probs_40_r',
#  'cad_probs_40_i',
#  'cad_probs_40_z',
#  'cad_probs_50_u',
#  'cad_probs_50_g',
#  'cad_probs_50_r',
#  'cad_probs_50_i',
#  'cad_probs_50_z',
#  'cad_probs_100_u',
#  'cad_probs_100_g',
#  'cad_probs_100_r',
#  'cad_probs_100_i',
#  'cad_probs_100_z',
#  'cad_probs_100_y',
#  'cad_probs_500_u',
#  'cad_probs_500_g',
#  'cad_probs_500_r',
#  'cad_probs_500_i',
#  'cad_probs_500_z',
#  'cad_probs_500_y',
#  'cad_probs_1000_u',
#  'cad_probs_1000_g',
#  'cad_probs_1000_r',
#  'cad_probs_1000_i',
#  'cad_probs_1000_z',
#  'cad_probs_1000_y',
#  'cad_probs_5000_u',
#  'cad_probs_5000_g',
#  'cad_probs_5000_r',
#  'cad_probs_5000_i',
#  'cad_probs_5000_z',
#  'cad_probs_5000_y',
#  'cad_probs_10000_u',
#  'cad_probs_10000_g',
#  'cad_probs_10000_r',
#  'cad_probs_10000_i',
#  'cad_probs_10000_z',
#  'cad_probs_10000_y',
#  'cad_probs_50000_u',
#  'cad_probs_50000_g',
#  'cad_probs_50000_r',
#  'cad_probs_50000_i',
#  'cad_probs_50000_z',
#  'cad_probs_50000_y',
#  'cad_probs_100000_u',
#  'cad_probs_100000_g',
#  'cad_probs_100000_r',
#  'cad_probs_100000_i',
#  'cad_probs_100000_z',
#  'cad_probs_100000_y',
#  'cad_probs_500000_u',
#  'cad_probs_500000_g',
#  'cad_probs_500000_r',
#  'cad_probs_500000_i',
#  'cad_probs_500000_z',
#  'cad_probs_500000_y',
#  'cad_probs_1000000_g',
#  'cads_avg_u',
#  'cads_avg_g',
#  'cads_avg_r',
#  'cads_avg_i',
#  'cads_avg_z',
#  'cads_avg_y',
#  'cads_med_u',
#  'cads_med_g',
#  'cads_med_r',
#  'cads_med_i',
#  'cads_med_z',
#  'cads_med_y',
#  'cads_std_u',
#  'cads_std_g',
#  'cads_std_r',
#  'cads_std_i',
#  'cads_std_z',
#  'cads_std_y',
#  'mean_u',
#  'mean_g',
#  'mean_r',
#  'mean_i',
#  'mean_z',
#  'mean_y',
#  'med_double_to_single_step_u',
#  'med_double_to_single_step_g',
#  'med_double_to_single_step_r',
#  'med_double_to_single_step_i',
#  'med_double_to_single_step_z',
#  'med_double_to_single_step_y',
#  'med_err_u',
#  'med_err_g',
#  'med_err_r',
#  'med_err_i',
#  'med_err_z',
#  'med_err_y',
#  'n_epochs_u',
#  'n_epochs_g',
#  'n_epochs_r',
#  'n_epochs_i',
#  'n_epochs_z',
#  'n_epochs_y',
#  'std_double_to_single_step_z',
#  'std_err_u',
#  'std_err_g',
#  'std_err_r',
#  'std_err_i',
#  'std_err_z',
#  'std_err_y',
#  'total_time_u',
#  'total_time_g',
#  'total_time_r',
#  'total_time_i',
#  'total_time_z',
#  'total_time_y',
#  'flux_min_fluxfactor',
#  'flux_max_fluxfactor',
#  'flux_mean_fluxfactor',
#  'flux_median_fluxfactor',
#  'flux_std_fluxfactor',
#  'flux_skew_fluxfactor',
#  'flux_err_min_fluxfactor',
#  'flux_err_max_fluxfactor',
#  'flux_err_mean_fluxfactor',
#  'flux_err_median_fluxfactor',
#  'flux_err_std_fluxfactor',
#  'flux_err_skew_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_fluxfactor',
#  'flux_by_flux_ratio_sq_skew_fluxfactor',
#  'flux_min_detected1_fluxfactor',
#  'flux_max_detected1_fluxfactor',
#  'flux_mean_detected1_fluxfactor',
#  'flux_median_detected1_fluxfactor',
#  'flux_std_detected1_fluxfactor',
#  'flux_err_min_detected1_fluxfactor',
#  'flux_err_max_detected1_fluxfactor',
#  'flux_err_mean_detected1_fluxfactor',
#  'flux_err_median_detected1_fluxfactor',
#  'flux_err_std_detected1_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_detected1_fluxfactor',
#  'flux_diff_fluxfactor',
#  'flux_dif2_fluxfactor',
#  'flux_w_mean_fluxfactor',
#  'flux_dif3_fluxfactor',
#  'flux_diff_detected1_fluxfactor',
#  'flux_dif2_detected1_fluxfactor',
#  'flux_w_mean_detected1_fluxfactor',
#  'flux_dif3_detected1_fluxfactor',
#  'flux_ratio_sq_sum_0_fluxfactor',
#  'flux_ratio_sq_sum_1_fluxfactor',
#  'flux_ratio_sq_sum_2_fluxfactor',
#  'flux_ratio_sq_sum_3_fluxfactor',
#  'flux_ratio_sq_sum_4_fluxfactor',
#  'flux_ratio_sq_sum_5_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_0_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_1_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_2_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_3_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_4_fluxfactor',
#  'flux_by_flux_ratio_sq_sum_5_fluxfactor',
#  'flux_dif2_0_fluxfactor',
#  'flux_w_mean_0_fluxfactor',
#  'flux_dif3_0_fluxfactor',
#  'flux_dif2_1_fluxfactor',
#  'flux_w_mean_1_fluxfactor',
#  'flux_dif3_1_fluxfactor',
#  'flux_dif2_2_fluxfactor',
#  'flux_w_mean_2_fluxfactor',
#  'flux_dif3_2_fluxfactor',
#  'flux_dif2_3_fluxfactor',
#  'flux_w_mean_3_fluxfactor',
#  'flux_dif3_3_fluxfactor',
#  'flux_dif2_4_fluxfactor',
#  'flux_w_mean_4_fluxfactor',
#  'flux_dif3_4_fluxfactor',
#  'flux_dif2_5_fluxfactor',
#  'flux_w_mean_5_fluxfactor',
#  'flux_dif3_5_fluxfactor',
#  '__linear_trend___0_',
#  '__linear_trend___1_',
#  '__linear_trend___2_',
#  '__linear_trend___3_',
#  '__linear_trend___4_',
#  '__linear_trend___5_',
#  '__freq1_amplitude1___0_',
#  '__freq1_amplitude1___1_',
#  '__freq1_amplitude1___2_',
#  '__freq1_amplitude1___3_',
#  '__freq1_amplitude1___4_',
#  '__freq1_amplitude1___5_',
#  '__freq1_amplitude2___0_',
#  '__freq1_amplitude2___1_',
#  '__freq1_amplitude2___2_',
#  '__freq1_amplitude2___3_',
#  '__freq1_amplitude2___4_',
#  '__freq1_amplitude2___5_',
#  '__freq1_amplitude3___0_',
#  '__freq1_amplitude3___1_',
#  '__freq1_amplitude3___2_',
#  '__freq1_amplitude3___3_',
#  '__freq1_amplitude3___4_',
#  '__freq1_amplitude3___5_',
#  '__freq1_amplitude4___0_',
#  '__freq1_amplitude4___1_',
#  '__freq1_amplitude4___2_',
#  '__freq1_amplitude4___3_',
#  '__freq1_amplitude4___4_',
#  '__freq1_amplitude4___5_',
#  '__freq1_freq___0_',
#  '__freq1_freq___1_',
#  '__freq1_freq___2_',
#  '__freq1_freq___3_',
#  '__freq1_freq___4_',
#  '__freq1_freq___5_',
#  '__freq1_rel_phase2___0_',
#  '__freq1_rel_phase2___1_',
#  '__freq1_rel_phase2___2_',
#  '__freq1_rel_phase2___3_',
#  '__freq1_rel_phase2___4_',
#  '__freq1_rel_phase2___5_',
#  '__freq1_rel_phase3___0_',
#  '__freq1_rel_phase3___1_',
#  '__freq1_rel_phase3___2_',
#  '__freq1_rel_phase3___3_',
#  '__freq1_rel_phase3___4_',
#  '__freq1_rel_phase3___5_',
#  '__freq1_rel_phase4___0_',
#  '__freq1_rel_phase4___1_',
#  '__freq1_rel_phase4___2_',
#  '__freq1_rel_phase4___3_',
#  '__freq1_rel_phase4___4_',
#  '__freq1_rel_phase4___5_',
#  '__freq2_amplitude1___0_',
#  '__freq2_amplitude1___1_',
#  '__freq2_amplitude1___2_',
#  '__freq2_amplitude1___3_',
#  '__freq2_amplitude1___4_',
#  '__freq2_amplitude1___5_',
#  '__freq2_amplitude2___0_',
#  '__freq2_amplitude2___1_',
#  '__freq2_amplitude2___2_',
#  '__freq2_amplitude2___3_',
#  '__freq2_amplitude2___4_',
#  '__freq2_amplitude2___5_',
#  '__freq2_amplitude3___0_',
#  '__freq2_amplitude3___1_',
#  '__freq2_amplitude3___2_',
#  '__freq2_amplitude3___3_',
#  '__freq2_amplitude3___4_',
#  '__freq2_amplitude3___5_',
#  '__freq2_amplitude4___0_',
#  '__freq2_amplitude4___1_',
#  '__freq2_amplitude4___2_',
#  '__freq2_amplitude4___3_',
#  '__freq2_amplitude4___4_',
#  '__freq2_amplitude4___5_',
#  '__freq2_freq___0_',
#  '__freq2_freq___1_',
#  '__freq2_freq___2_',
#  '__freq2_freq___3_',
#  '__freq2_freq___4_',
#  '__freq2_freq___5_',
#  '__freq2_rel_phase2___0_',
#  '__freq2_rel_phase2___1_',
#  '__freq2_rel_phase2___2_',
#  '__freq2_rel_phase2___3_',
#  '__freq2_rel_phase2___4_',
#  '__freq2_rel_phase2___5_',
#  '__freq2_rel_phase3___0_',
#  '__freq2_rel_phase3___1_',
#  '__freq2_rel_phase3___2_',
#  '__freq2_rel_phase3___3_',
#  '__freq2_rel_phase3___4_',
#  '__freq2_rel_phase3___5_',
#  '__freq2_rel_phase4___0_',
#  '__freq2_rel_phase4___1_',
#  '__freq2_rel_phase4___2_',
#  '__freq2_rel_phase4___3_',
#  '__freq2_rel_phase4___4_',
#  '__freq2_rel_phase4___5_',
#  '__freq3_amplitude1___0_',
#  '__freq3_amplitude1___1_',
#  '__freq3_amplitude1___2_',
#  '__freq3_amplitude1___3_',
#  '__freq3_amplitude1___4_',
#  '__freq3_amplitude1___5_',
#  '__freq3_amplitude2___0_',
#  '__freq3_amplitude2___1_',
#  '__freq3_amplitude2___2_',
#  '__freq3_amplitude2___3_',
#  '__freq3_amplitude2___4_',
#  '__freq3_amplitude2___5_',
#  '__freq3_amplitude3___0_',
#  '__freq3_amplitude3___1_',
#  '__freq3_amplitude3___2_',
#  '__freq3_amplitude3___3_',
#  '__freq3_amplitude3___4_',
#  '__freq3_amplitude3___5_',
#  '__freq3_amplitude4___0_',
#  '__freq3_amplitude4___1_',
#  '__freq3_amplitude4___2_',
#  '__freq3_amplitude4___3_',
#  '__freq3_amplitude4___4_',
#  '__freq3_amplitude4___5_',
#  '__freq3_freq___0_',
#  '__freq3_freq___1_',
#  '__freq3_freq___2_',
#  '__freq3_freq___3_',
#  '__freq3_freq___4_',
#  '__freq3_freq___5_',
#  '__freq3_rel_phase2___0_',
#  '__freq3_rel_phase2___1_',
#  '__freq3_rel_phase2___2_',
#  '__freq3_rel_phase2___3_',
#  '__freq3_rel_phase2___4_',
#  '__freq3_rel_phase2___5_',
#  '__freq3_rel_phase3___0_',
#  '__freq3_rel_phase3___1_',
#  '__freq3_rel_phase3___2_',
#  '__freq3_rel_phase3___3_',
#  '__freq3_rel_phase3___4_',
#  '__freq3_rel_phase3___5_',
#  '__freq3_rel_phase4___0_',
#  '__freq3_rel_phase4___1_',
#  '__freq3_rel_phase4___2_',
#  '__freq3_rel_phase4___3_',
#  '__freq3_rel_phase4___4_',
#  '__freq3_rel_phase4___5_',
#  '__freq1_signif___0_',
#  '__freq1_signif___1_',
#  '__freq1_signif___2_',
#  '__freq1_signif___3_',
#  '__freq1_signif___4_',
#  '__freq1_signif___5_',
#  '__freq_signif_ratio_21___0_',
#  '__freq_signif_ratio_21___1_',
#  '__freq_signif_ratio_21___2_',
#  '__freq_signif_ratio_21___3_',
#  '__freq_signif_ratio_21___4_',
#  '__freq_signif_ratio_21___5_',
#  '__freq_signif_ratio_31___0_',
#  '__freq_signif_ratio_31___1_',
#  '__freq_signif_ratio_31___2_',
#  '__freq_signif_ratio_31___3_',
#  '__freq_signif_ratio_31___4_',
#  '__freq_signif_ratio_31___5_',
#  '__freq_varrat___0_',
#  '__freq_varrat___1_',
#  '__freq_varrat___2_',
#  '__freq_varrat___3_',
#  '__freq_varrat___4_',
#  '__freq_varrat___5_',
#  '__freq_y_offset___0_',
#  '__freq_y_offset___1_',
#  '__freq_y_offset___2_',
#  '__freq_y_offset___3_',
#  '__freq_y_offset___4_',
#  '__freq_y_offset___5_',
#  'fluxdiff_min',
#  'fluxdiff_max',
#  'fluxdiff_mean',
#  'fluxdiff_median',
#  'fluxdiff_std',
#  'fluxdiff_skew',
#  'fluxdiff_min_detected1',
#  'fluxdiff_max_detected1',
#  'fluxdiff_mean_detected1',
#  'fluxdiff_median_detected1',
#  'fluxdiff_diff',
#  'fluxdiff_dif2',
#  'fluxdiff_diff_detected1',
#  'fluxdiff_dif2_detected1',
#  'fluxdiff_min_0',
#  'fluxdiff_min_1',
#  'fluxdiff_min_2',
#  'fluxdiff_min_3',
#  'fluxdiff_min_4',
#  'fluxdiff_min_5',
#  'fluxdiff_max_0',
#  'fluxdiff_max_1',
#  'fluxdiff_max_2',
#  'fluxdiff_max_3',
#  'fluxdiff_max_4',
#  'fluxdiff_max_5',
#  'fluxdiff_mean_0',
#  'fluxdiff_mean_1',
#  'fluxdiff_mean_2',
#  'fluxdiff_mean_3',
#  'fluxdiff_mean_4',
#  'fluxdiff_mean_5',
#  'fluxdiff_median_0',
#  'fluxdiff_median_1',
#  'fluxdiff_median_2',
#  'fluxdiff_median_3',
#  'fluxdiff_median_4',
#  'fluxdiff_median_5',
#  'fluxdiff_std_0',
#  'fluxdiff_std_1',
#  'fluxdiff_std_2',
#  'fluxdiff_std_3',
#  'fluxdiff_std_4',
#  'fluxdiff_std_5',
#  'fluxdiff_skew_0',
#  'fluxdiff_skew_1',
#  'fluxdiff_skew_2',
#  'fluxdiff_skew_3',
#  'fluxdiff_skew_4',
#  'fluxdiff_skew_5',
#  'fluxdiff_diff_0',
#  'fluxdiff_dif2_0',
#  'fluxdiff_diff_1',
#  'fluxdiff_dif2_1',
#  'fluxdiff_diff_2',
#  'fluxdiff_dif2_2',
#  'fluxdiff_diff_3',
#  'fluxdiff_dif2_3',
#  'fluxdiff_diff_4',
#  'fluxdiff_dif2_4',
#  'fluxdiff_diff_5',
#  'fluxdiff_dif2_5']
